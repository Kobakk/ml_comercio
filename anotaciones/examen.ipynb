# %% [markdown]
# ### importaciones

# %%
import numpy as np
from sklearn.datasets import load_iris

# %% [markdown]
# ### ejemplo desde 0:

# %%
np.random.seed(42)
n_samples = 1000

data = {
    'mes_contrato': np.random.randint(1, 72, n_samples),
    'cargo_mensual': np.random.uniform(20, 120, n_samples),
    'llamadas_soporte': np.random.randint(0, 10, n_samples),
    'satisfaccion': np.random.uniform(0, 1, n_samples)
}
print(data)
# Out:
# {'mes_contrato': array([52, 15, 61, 21, 24,  3, 22, 53,  2, 30, 38,  2, 64, 60, 21, 33, 58,
#        22, 49, 59, 42, 60, 15, 62, 62, 47, 62, 51, 55, 64,  3, 51,  7, 21,
#        39, 18,  4, 60, 14,  9, 53,  2, 60, 71, 44,  8, 47, 35, 36, 50,  4,
#         2,  6, 54,  4, 54, 63, 18, 44, 34, 62, 14, 48, 15, 62, 40, 53, 24,
#        26, 60, 41, 29, 15, 45, 65, 71,  9,  1,  8, 63, 11,  8, 35, 35, 33,
#         5, 41, 28,  7, 12, 34, 33, 48, 23, 62, 37, 44, 35, 65, 47,  3,  1,
#         5, 14, 27,  9, 15, 42, 51, 63, 52,  4, 23, 15, 43, 29, 36, 13, 32,
#        71, 59, 28, 66, 42, 45, 62, 57,  6, 28, 28, 44, 30, 62, 62,  1, 27,
#        62,  3, 70, 27,  9, 62, 37, 51, 44, 24, 59, 32, 52, 62, 58, 52, 12,
#        39,  2,  3, 56, 59,  2,  2, 54,  1, 19,  2, 53, 44, 32, 70, 32, 68,
#        55, 56, 17, 38, 24, 69, 70, 11, 16, 59, 70,  3, 20, 59, 36, 19, 67,
#        19, 20, 71, 52, 33, 40, 39,  1, 11, 57, 50, 23, 31, 42,  7, 16, 60,
# ...

# %%
churn_prob = (
    0.1 * data['llamadas_soporte'] +

)

# %% [markdown]
# ### Ejemplo con el dataset Iris  :

# %%
iris = load_iris()
print(iris.data.shape)
# Out:
# (150, 4)

# %% [markdown]
# #### caracteristicas númericas

# %% [markdown]
# 1. Longitud sépalo: cm
# 2. Ancho sépalo: cm
# 3. Longitud de pétalo: cm
# 4. Ancho de pétalo: cm
#
# Podemos realizar calculos estadísticos sobre estos valores categóricos.
