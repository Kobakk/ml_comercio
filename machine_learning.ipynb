# %% [markdown]
# ### Entrenamiento supervisado

# %% [markdown]
# 1. planteamiento de los datos
# - datos etiquetados ( datos, texto, fotos)
# 2. Algoritmos
# - uso de árboles de decisión (bosques)
# - sistemas de regresión (mínimos cuadrados, logística)
# - clasificador bayesiano ingenuo (Naive-Bayes)
# - máquinas de vector soporte
# - redes neuronales
# Para inferir en el output de datos de salida.

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Regresión lineal

# %% [markdown]
# - y = mx + b
#
# 1. Aplicado  a la predicción de **aumento de precio de casas**.
#
# - y: lo que queremos predecir (precio casa)
# - x: lo que conocemos (metros cuadrados)
# - m: pendiente de la línea (cuánto sube el precio por metro cuadrado)
# - b: intercepto (precio base cuando x =0 )

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Entrenamiento no supervisado

# %%
import pandas as pd
import sklearn
import seaborn
from sklearn.datasets import  load_iris

# %%
iris = load_iris(as_frame=True)
#print(iris)
type(iris)
iris.get('data')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df = pd.read_csv(iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv(iris)
#
# File ~\Documents\entornosPy\merc\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
# ...
